# %% [markdown]
# * Open a file
# * Read or write - Performing operation
# * Close the file

# %% [markdown]
# * "r" - Read - Default value. Opens a file for reading, error if the file does not exist, The file pointer exists at the beginning .
# * "a" - Append - Opens a file for appending, creates the file if it does not exist , The file pointer exists at the end .
# * "w" - Write - Opens a file for writing, creates the file if it does not exist, The file pointer exists at the beginning of the file .
# * "x" - Create - Creates the specified file, returns an error if the file exists
# ------------------------------------------------------------------------------
#
# * r+	It opens the file to read and write both.
# * w+	It opens the file to write and read both.
# * a+	It opens a file to append and read both.
# -------------------------------------------------------------------------------
#
# * "t" - Text - Default value. Text mode
#
# * "b" - Binary - Binary mode (e.g. images)

# %%
file1 = open("file.txt","r") # open text-file in read-mode
file2 = open("file.txt","w") # open text-file in write-mode
file3 = open("file.txt","rb") # open image-file in read-mode

print('-------------------------')

file1.close() # for good-practice
file2.close() # for good-practice
file3.close() # for good-practice

# %%
print('we can also use try-except block')
try:
   fileptr = open("file.txt")
   # perform file operations
finally:
   fileptr.close()

# %% [markdown]
# ## some methods
# 1.  file.close() ->	It closes the opened file. The file once closed, it can't be
# read or write anymore.
# 2. 	File.fush() ->	It flushes the internal buffer.
# 3. 	File.fileno()	It returns the file descriptor used by the underlying implementation to request I/O from the OS.
# 4.	File.isatty()	It returns true if the file is connected to a TTY device, otherwise returns false.
# 5. 	File.next()	It returns the next line from the file.
# 6.	File.read([size])	It reads the file for the specified size.
# 7.	File.readline([size])	It reads one line from the file and places the file pointer to the beginning of the new line.
# 8.	File.readlines([sizehint])	It returns a list containing all the lines of the file. It reads the file until the EOF occurs using readline() function.
# 9.	File.seek(offset[,from)	It modifies the position of the file pointer to a specified offset with the specified reference.
# 10.	File.tell()	It returns the current position of the file pointer within the file.
# 11.	File.truncate([size])	It truncates the file to the optional specified size.
# 12.	File.write(str)	It writes the specified string to a file
# 13.	File.writelines(seq)	It writes a sequence of the strings to a file.

# %% [markdown]
# ### Removing file we use os library

# %%
# os.remove()
import os
if os.path.exists("demofile.txt"):
  os.remove("demofile.txt")
else:
  print("The file does not exist")

# %%
# get current working directory path
import os
os.getcwd()
# Out:
# '/content'

# %%
# we can alson change directory
import os
# Changing current directory with the new directiory
os.chdir("C:\\Users\\DEVANSH SHARMA\\Documents")
#It will display the current working directory
os.getcwd()

# %%
#removing the new directory
import os
os.rmdir("directory_name")

# %%
import platform

x = platform.system()
print(x)
# Out:
# Linux

# %%
# We will import the sys module
import sys

# we will import sys.path
print(sys.path)
# Out:
# ['/content', '/env/python', '/usr/lib/python310.zip', '/usr/lib/python3.10', '/usr/lib/python3.10/lib-dynload', '', '/usr/local/lib/python3.10/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.10/dist-packages/IPython/extensions', '/root/.ipython']

# %% [markdown]
# # Exception handling
# * The ***try*** block lets you test a block of code for errors.
# * The ***except*** block lets you handle the error.
# * The ***else*** block lets you execute code when there is no error.
# * The ***finally*** block lets you execute code, regardless of the result of the try- and except blocks.

# %%
try:
  print("Hello")
except:
  print("Something went wrong")
else:
  print("Nothing went wrong")
finally:
  print("sbb clear hai bhai")
# Out:
# Hello
# Nothing went wrong
# sbb clear hai bhai

# %%
num1=0
try:
      reci = 1 / num1
except ZeroDivisionError:  # aise pre define exception handle hoti hai
      print( "We cannot divide by zero" )
else:
      print ( reci )
finally:
      print('finish')
# Out:
# We cannot divide by zero
# finish

# %% [markdown]
# ###Raise a exception
# * If we wish to use raise to generate an exception

# %%
x = int(input())
if x < 0:
  raise Exception("Sorry, no numbers below zero")
else:
  print(x)
# Out:
# 5
# 5

# %% [markdown]
# ### Assertion statement
# * if assert statement is true then proceed other wise raise exception

# %%
try:
  a = int(input())
  assert a%2 == 0
  print('a is even')
except AssertionError:
  print('please give even input')

# %% [markdown]
# ## List of all Exception

# %%
import builtins
list_of_exception_names = [name for name, value in builtins.__dict__.items() if isinstance(value, type) and issubclass(value, BaseException)]
print(list_of_exception_names)
print('ZeroDivisionError' in list_of_exception_names)
# Out:
# ['BaseException', 'Exception', 'TypeError', 'StopAsyncIteration', 'StopIteration', 'GeneratorExit', 'SystemExit', 'KeyboardInterrupt', 'ImportError', 'ModuleNotFoundError', 'OSError', 'EnvironmentError', 'IOError', 'EOFError', 'RuntimeError', 'RecursionError', 'NotImplementedError', 'NameError', 'UnboundLocalError', 'AttributeError', 'SyntaxError', 'IndentationError', 'TabError', 'LookupError', 'IndexError', 'KeyError', 'ValueError', 'UnicodeError', 'UnicodeEncodeError', 'UnicodeDecodeError', 'UnicodeTranslateError', 'AssertionError', 'ArithmeticError', 'FloatingPointError', 'OverflowError', 'ZeroDivisionError', 'SystemError', 'ReferenceError', 'MemoryError', 'BufferError', 'Warning', 'UserWarning', 'EncodingWarning', 'DeprecationWarning', 'PendingDeprecationWarning', 'SyntaxWarning', 'RuntimeWarning', 'FutureWarning', 'ImportWarning', 'UnicodeWarning', 'BytesWarning', 'ResourceWarning', 'ConnectionError', 'BlockingIOError', 'BrokenPipeError', 'ChildProcessError', 'ConnectionAbortedE
# ...

# %%
print(list)
# Out:
# <class 'list'>
